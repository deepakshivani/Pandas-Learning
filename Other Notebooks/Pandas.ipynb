# %%
import numpy as np
import pandas as pd

# %%
arr1=np.array([0,0,0])
arr1
# Out:
# array([0, 0, 0])

# %%
arr2=np.array([1,2,3])
arr2
# Out:
# array([1, 2, 3])

# %%
ser=pd.Series([1,2,3,4,5], index=["A", "B", "C", "D", "E"])

# %%
ser[["A", "B"]]
# Out:
# A    1
# B    2
# dtype: int64

# %%
ser.product()
# Out:
# 120

# %%
df1=pd.DataFrame([arr1, arr2], index=["Q", "R"])

# %%
df1
# Out:
#    0  1  2
# Q  0  0  0
# R  1  2  3

# %%
ser1=pd.read_csv("movies_metadata.csv", usecols=["budget"])
ser1=ser1.squeeze()
ser1
# Out:
# 0     30000000
# 1     65000000
# 2            0
# 3     16000000
# 4            0
# 5     60000000
# 6     58000000
# 7            0
# 8     35000000
# 9     58000000
# 10    62000000
# 11           0
# 12           0
# 13    44000000
# 14    98000000
# 15    52000000
# 16    16500000
# 17     4000000
# 18    30000000
# 19    60000000
# 20    30250000
# 21           0
# 22    50000000
# 23           0
# 24     3600000
# 25           0
# 26    12000000
# 27           0
# 28    18000000
# 29           0
# 30    29500000
# 31           0
# 32    30000000
# 33           0
# 34    11000000
# 35           0
# 36           0
# 37    12000000
# 38           0
# 39           0
# 40    10000000
# 41    19000000
# 42    18000000
# 43    20000000
# 44    10000000
# 45    33000000
# 46    55000000
# 47           0
# 48     6000000
# Name: budget, dtype: int64

# %%
ser1[[0,2,5]]
# Out:
# 0    30000000
# 2           0
# 5    60000000
# Name: budget, dtype: int64

# %%
ser1.describe()
# Out:
# count    4.900000e+01
# mean     2.154796e+07
# std      2.433495e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.200000e+07
# 75%      3.300000e+07
# max      9.800000e+07
# Name: budget, dtype: float64

# %%
ser1.apply(lambda x : np.cos(x))
# Out:
# 0    -0.265429
# 1    -0.314827
# 2     1.000000
# 3     0.846107
# 4     1.000000
# 5    -0.859094
# 6    -0.313018
# 7     1.000000
# 8     0.998668
# 9    -0.313018
# 10   -0.984230
# 11    1.000000
# 12    1.000000
# 13   -0.999691
# 14   -0.885248
# 15    0.967355
# 16   -0.927407
# 17    0.140077
# 18   -0.265429
# 19   -0.859094
# 20    0.983976
# 21    1.000000
# 22    0.564187
# 23    1.000000
# 24    0.279780
# 25    1.000000
# 26   -0.409238
# 27    1.000000
# 28    0.988323
# 29    1.000000
# 30    0.432651
# 31    1.000000
# 32   -0.265429
# 33    1.000000
# 34   -0.702698
# 35    1.000000
# 36    1.000000
# 37   -0.409238
# 38    1.000000
# 39    1.000000
# 40   -0.907270
# 41    0.872484
# 42    0.988323
# 43    0.646279
# 44   -0.907270
# 45    0.720167
# 46    0.684796
# 47    1.000000
# 48   -0.543490
# Name: budget, dtype: float64

# %%
ser1[0]="heuy"

# %%
ser1.describe()
# Out:
# count     49
# unique    27
# top        0
# freq      17
# Name: budget, dtype: int64

# %%
ser1.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 49 entries, 0 to 48
# Series name: budget
# Non-Null Count  Dtype
# --------------  -----
# 49 non-null     object
# dtypes: object(1)
# memory usage: 520.0+ bytes

# %%
ser1.describe()
# Out:
# count     49
# unique    27
# top        0
# freq      17
# Name: budget, dtype: int64

# %%
df=pd.read_csv("movies_metadata.csv")

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=49, step=1),
#  Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#         'imdb_id', 'original_language', 'original_title', 'overview',
#         'popularity', 'poster_path', 'production_companies',
#         'production_countries', 'release_date', 'revenue', 'runtime',
#         'spoken_languages', 'status', 'tagline', 'title', 'video',
#         'vote_average', 'vote_count'],
#        dtype='object')]

# %%
df.shape
# Out:
# (49, 24)

# %%
df[0:1]
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#    release_date    revenue runtime                          spoken_languages  \
# 0    1995-10-30  373554033    81.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  tagline      title  video vote_average vote_count
# 0  Released      NaN  Toy Story  False          7.7       5415
#
# [1 rows x 24 columns]

# %%
df["new2"]=[x*2 for x in range(49)]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.insert()
#
# TypeError: DataFrame.insert() missing 3 required positional arguments: 'loc', 'column', and 'value'

# %%
pd.concat([df1, df])

# %%
df

# %%
df.dropna(how="all")

# %%
df.dropna(axis=1).info()

# %%
df.dropna(subset=[0], axis=1)

# %%
df.drop(axis=1, labels=["vote_count"])

# %%
df["belongs_to_collection"].fillna(0)

# %%
df

# %%
df["belongs_to_collection"]=df["belongs_to_collection"].fillna(pd.Series([{'id':1, 'NAME':5}] * df.shape[0]))

# %%
df["belongs_to_collection"]=df["belongs_to_collection"].fillna(pd.Series([{'KEY':1,'VALUE':2}]*df.shape[0]))

# %%
df.sort_values("budget", ascending=False, ignore_index=True)
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False                             {'KEY': 1, 'VALUE': 2}  98000000
# 1   False                             {'KEY': 1, 'VALUE': 2}  65000000
# 2   False                             {'KEY': 1, 'VALUE': 2}  62000000
# 3   False                             {'KEY': 1, 'VALUE': 2}  60000000
# 4   False                             {'KEY': 1, 'VALUE': 2}  60000000
# 5   False                             {'KEY': 1, 'VALUE': 2}  58000000
# 6   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 7   False  {'id': 136214, 'name': 'Pocahontas Collection'...  55000000
# 8   False                             {'KEY': 1, 'VALUE': 2}  52000000
# 9   False                             {'KEY': 1, 'VALUE': 2}  50000000
# 10  False                             {'KEY': 1, 'VALUE': 2}  44000000
# 11  False                             {'KEY': 1, 'VALUE': 2}  35000000
# ...

# %%
df["homepage"].replace("www.imdb.com", "www.imdb1.com", inplace=True)

# %%
df1=df[["budget", "revenue"]]

# %%
df1.sort_values(0, axis=1, ascending=False)
# Out:
#       revenue    budget
# 0   373554033  30000000
# 1   262797249  65000000
# 2           0         0
# 3    81452156  16000000
# 4    76578911         0
# 5   187436818  60000000
# 6           0  58000000
# 7           0         0
# 8    64350171  35000000
# 9   352194034  58000000
# 10  107879496  62000000
# 11          0         0
# 12   11348324         0
# 13   13681765  44000000
# 14   10017322  98000000
# 15  116112375  52000000
# 16  135000000  16500000
# 17    4300000   4000000
# 18  212385533  30000000
# 19   35431113  60000000
# 20  115101622  30250000
# 21          0         0
# 22   30303072  50000000
# 23          0         0
# 24   49800000   3600000
# 25          0         0
# 26   27400000  12000000
# 27          0         0
# 28    1738611  18000000
# 29  180000000         0
# 30  168840000  29500000
# 31          0         0
# 32  254134910  30000000
# 33          0         0
# 34   39363635  11000000
# 35          0         0
# 36          0         0
# ...

# %%
df.sort_values(["budget", "revenue"], ascending=False)
# Out:
#     adult                              belongs_to_collection    budget  \
# 14  False                             {'KEY': 1, 'VALUE': 2}  98000000
# 1   False                             {'KEY': 1, 'VALUE': 2}  65000000
# 10  False                             {'KEY': 1, 'VALUE': 2}  62000000
# 5   False                             {'KEY': 1, 'VALUE': 2}  60000000
# 19  False                             {'KEY': 1, 'VALUE': 2}  60000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 6   False                             {'KEY': 1, 'VALUE': 2}  58000000
# 46  False  {'id': 136214, 'name': 'Pocahontas Collection'...  55000000
# 15  False                             {'KEY': 1, 'VALUE': 2}  52000000
# 22  False                             {'KEY': 1, 'VALUE': 2}  50000000
# 13  False                             {'KEY': 1, 'VALUE': 2}  44000000
# 8   False                             {'KEY': 1, 'VALUE': 2}  35000000
# ...

# %%
df["rank"]= df["budget"].rank()

# %%
df.sort_values("rank")
# Out:
#     adult                              belongs_to_collection    budget  \
# 31  False                             {'KEY': 1, 'VALUE': 2}         0
# 23  False                             {'KEY': 1, 'VALUE': 2}         0
# 47  False                             {'KEY': 1, 'VALUE': 2}         0
# 25  False                             {'KEY': 1, 'VALUE': 2}         0
# 27  False                             {'KEY': 1, 'VALUE': 2}         0
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 11  False                             {'KEY': 1, 'VALUE': 2}         0
# 29  False                             {'KEY': 1, 'VALUE': 2}         0
# 21  False                             {'KEY': 1, 'VALUE': 2}         0
# 7   False                             {'KEY': 1, 'VALUE': 2}         0
# 35  False                             {'KEY': 1, 'VALUE': 2}         0
# 36  False                             {'KEY': 1, 'VALUE': 2}         0
# ...

# %%
df["budget"]=df["budget"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  49 non-null     bool
#  1   belongs_to_collection  49 non-null     object
#  2   budget                 49 non-null     category
#  3   genres                 49 non-null     object
#  4   homepage               5 non-null      object
#  5   id                     49 non-null     int64
#  6   imdb_id                49 non-null     object
#  7   original_language      49 non-null     object
#  8   original_title         49 non-null     object
#  9   overview               48 non-null     object
#  10  popularity             49 non-null     float64
#  11  poster_path            49 non-null     object
#  12  production_companies   49 non-null     object
#  13  production_countries   49 non-null     object
# ...

# %%
df["release_date"]=pd.to_datetime(df["release_date"])

# %%
df["release_date"]
# Out:
# 0    1995-10-30
# 1    1995-12-15
# 2    1995-12-22
# 3    1995-12-22
# 4    1995-02-10
# 5    1995-12-15
# 6    1995-12-15
# 7    1995-12-22
# 8    1995-12-22
# 9    1995-11-16
# 10   1995-11-17
# 11   1995-12-22
# 12   1995-12-22
# 13   1995-12-22
# 14   1995-12-22
# 15   1995-11-22
# 16   1995-12-13
# 17   1995-12-09
# 18   1995-11-10
# 19   1995-11-21
# 20   1995-10-20
# 21   1995-10-27
# 22   1995-10-06
# 23   1995-10-27
# 24   1995-10-27
# 25   1995-12-15
# 26   1995-10-20
# 27   1995-09-27
# 28   1995-05-16
# 29   1995-08-11
# 30   1995-12-29
# 31   1996-09-18
# 32   1995-07-18
# 33   1995-11-08
# 34   1995-12-29
# 35   1995-10-20
# 36   1995-11-17
# 37   1995-07-19
# 38   1995-12-15
# 39   1995-12-29
# 40   1995-10-06
# 41   1995-12-29
# 42   1995-08-18
# 43   1995-05-20
# 44   1995-10-06
# 45   1995-09-22
# 46   1995-06-14
# 47   1995-05-05
# 48   1995-07-19
# Name: release_date, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  49 non-null     bool
#  1   belongs_to_collection  49 non-null     object
#  2   budget                 49 non-null     category
#  3   genres                 49 non-null     object
#  4   homepage               5 non-null      object
#  5   id                     49 non-null     int64
#  6   imdb_id                49 non-null     object
#  7   original_language      49 non-null     object
#  8   original_title         49 non-null     object
#  9   overview               48 non-null     object
#  10  popularity             49 non-null     float64
#  11  poster_path            49 non-null     object
#  12  production_companies   49 non-null     object
#  13  production_countries   49 non-null     object
# ...

# %%
df[df["homepage"].notnullll()]
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 24  False                             {'KEY': 1, 'VALUE': 2}   3600000
# 45  False                             {'KEY': 1, 'VALUE': 2}  33000000
# 48  False                             {'KEY': 1, 'VALUE': 2}   6000000
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 24  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 45  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 48  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#                                              homepage   id    imdb_id  \
# 0                http://toystory.disney.com/toy-story  862  tt0114709
# ...

# %%
df
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# ...

# %%
df["budget"].duplicated(keep=False)
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19    False
# 20     True
# 21    False
# 22     True
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34     True
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42    False
# 43     True
# 44    False
# 45     True
# 46     True
# 47    False
# 48     True
# Name: budget, dtype: bool

# %%
df.drop_duplicates(subset=["budget"], keep="last")
# Out:
#     adult                              belongs_to_collection    budget  \
# 1   False                                                NaN  65000000
# 3   False                                                NaN  16000000
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 13  False                                                NaN  44000000
# 14  False                                                NaN  98000000
# 15  False                                                NaN  52000000
# 16  False                                                NaN  16500000
# 17  False                                                NaN   4000000
# 19  False                                                NaN  60000000
# 20  False  {'id': 91698, 'name': 'Chili Palmer Collection...  30250000
# ...

# %%
df.set_index("imdb_id", drop=False, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.loc[0:1, ["budget"]]
# Out:
#      budget
# 0  30000000
# 1  65000000

# %%
df.loc[0:6]
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# ...

# %%
df1=df.loc[:,"budget"]

# %%
df1[0]=20
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_13072\2378009433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[0]=20

# %%
df1
# Out:
# 0           20
# 1     65000000
# 2            0
# 3     16000000
# 4            0
# 5     60000000
# 6     58000000
# 7            0
# 8     35000000
# 9     58000000
# 10    62000000
# 11           0
# 12           0
# 13    44000000
# 14    98000000
# 15    52000000
# 16    16500000
# 17     4000000
# 18    30000000
# 19    60000000
# 20    30250000
# 21           0
# 22    50000000
# 23           0
# 24     3600000
# 25           0
# 26    12000000
# 27           0
# 28    18000000
# 29           0
# 30    29500000
# 31           0
# 32    30000000
# 33           0
# 34    11000000
# 35           0
# 36           0
# 37    12000000
# 38           0
# 39           0
# 40    10000000
# 41    19000000
# 42    18000000
# 43    20000000
# 44    10000000
# 45    33000000
# 46    55000000
# 47           0
# 48     6000000
# Name: budget, dtype: int64

# %%
df2=df.copy()

# %%
df2["budget"][0]=8547
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_13072\3071400968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["budget"][0]=8547

# %%
df
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...        15
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# ...

# %%
df1
# Out:
# 0           15
# 1     65000000
# 2            0
# 3     16000000
# 4            0
# 5     60000000
# 6     58000000
# 7            0
# 8     35000000
# 9     58000000
# 10    62000000
# 11           0
# 12           0
# 13    44000000
# 14    98000000
# 15    52000000
# 16    16500000
# 17     4000000
# 18    30000000
# 19    60000000
# 20    30250000
# 21           0
# 22    50000000
# 23           0
# 24     3600000
# 25           0
# 26    12000000
# 27           0
# 28    18000000
# 29           0
# 30    29500000
# 31           0
# 32    30000000
# 33           0
# 34    11000000
# 35           0
# 36           0
# 37    12000000
# 38           0
# 39           0
# 40    10000000
# 41    19000000
# 42    18000000
# 43    20000000
# 44    10000000
# 45    33000000
# 46    55000000
# 47           0
# 48     6000000
# Name: budget, dtype: int64

# %%
df.iloc[1,2]=8542217852

# %%
df5=df["budget"]

# %%
df5[1]=4512
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_13072\1474146957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5[1]=4512

# %%
df[df["budget"]==541245442][0]=987456321
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_13072\1924654397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df["budget"]==541245442][0]=987456321

# %%
df.iloc[[0, 1, 2], [2, 4]]=[[400000, "www.some.com"], [789456, "www.pospstar.com"], [1234785, "www.olive.com"]]

# %%
df.loc[df["budget"]==5412055452, "budget"]=8520

# %%
df.rename(columns={"homepage":"website"})
# Out:
#          adult                              belongs_to_collection    budget  \
# 0        False  {'id': 10194, 'name': 'Toy Story Collection', ...    400000
# 1   5412055452                                         5412055452      8520
# 2        False  {'id': 119050, 'name': 'Grumpy Old Men Collect...   1234785
# 3        False                                                NaN  16000000
# 4        False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5        False                                                NaN  60000000
# 6        False                                                NaN  58000000
# 7        False                                                NaN         0
# 8        False                                                NaN  35000000
# 9        False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10       False                                                NaN  62000000
# ...

# %%
df
# Out:
#          adult                              belongs_to_collection    budget  \
# 0        False  {'id': 10194, 'name': 'Toy Story Collection', ...    400000
# 1   5412055452                                         5412055452      8520
# 2        False  {'id': 119050, 'name': 'Grumpy Old Men Collect...   1234785
# 3        False                                                NaN  16000000
# 4        False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5        False                                                NaN  60000000
# 6        False                                                NaN  58000000
# 7        False                                                NaN         0
# 8        False                                                NaN  35000000
# 9        False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10       False                                                NaN  62000000
# ...

# %%
df.drop(axis=1, labels=["budget"])
# Out:
#          adult                              belongs_to_collection  \
# 0        False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1   5412055452                                         5412055452
# 2        False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3        False                                                NaN
# 4        False  {'id': 96871, 'name': 'Father of the Bride Col...
# 5        False                                                NaN
# 6        False                                                NaN
# 7        False                                                NaN
# 8        False                                                NaN
# 9        False  {'id': 645, 'name': 'James Bond Collection', '...
# 10       False                                                NaN
# 11       False                                                NaN
# 12       False  {'id': 117693, 'name': 'Balto Collection', 'po...
# ...

# %%
df.sample(frac=0.1)
# Out:
#     adult                              belongs_to_collection    budget  \
# 26  False                                                NaN  12000000
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...    400000
# 25  False                                                NaN         0
# 22  False                                                NaN  50000000
# 18  False  {'id': 3167, 'name': 'Ace Ventura Collection',...  30000000
#
#                                                genres      homepage     id  \
# 26  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           NaN   9263
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  www.some.com    862
# 25                      [{'id': 18, 'name': 'Drama'}]           NaN  16420
# 22  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...           NaN   9691
# 18  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...           NaN   9273
#
#       imdb_id original_language                  original_title  \
# ...

# %%
df1=df.loc[:, ["budget", "revenue"]]
df1.sample(n=2, axis=1)
# Out:
#       budget     revenue
# 0     400000   373554033
# 1       8520  5412055452
# 2    1234785           0
# 3   16000000    81452156
# 4          0    76578911
# 5   60000000   187436818
# 6   58000000           0
# 7          0           0
# 8   35000000    64350171
# 9   58000000   352194034
# 10  62000000   107879496
# 11         0           0
# 12         0    11348324
# 13  44000000    13681765
# 14  98000000    10017322
# 15  52000000   116112375
# 16  16500000   135000000
# 17   4000000     4300000
# 18  30000000   212385533
# 19  60000000    35431113
# 20  30250000   115101622
# 21         0           0
# 22  50000000    30303072
# 23         0           0
# 24   3600000    49800000
# 25         0           0
# 26  12000000    27400000
# 27         0           0
# 28  18000000     1738611
# 29         0   180000000
# 30  29500000   168840000
# 31         0           0
# 32  30000000   254134910
# 33         0           0
# 34  11000000    39363635
# 35         0           0
# ...

# %%
df.nlargest(10, columns="budget")
# Out:
#     adult                              belongs_to_collection    budget  \
# 14  False                                                NaN  98000000
# 10  False                                                NaN  62000000
# 5   False                                                NaN  60000000
# 19  False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 46  False  {'id': 136214, 'name': 'Pocahontas Collection'...  55000000
# 15  False                                                NaN  52000000
# 22  False                                                NaN  50000000
# 13  False                                                NaN  44000000
#
#                                                genres  \
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
df1.nlargest(10, columns=["budget", "revenue"])
# Out:
#       budget    revenue
# 14  98000000   10017322
# 10  62000000  107879496
# 19  60000000  197436818
# 5   60000000  187436818
# 9   58000000  352194034
# 6   58000000          0
# 46  55000000  346079773
# 15  52000000  116112375
# 22  50000000   30303072
# 13  44000000   13681765

# %%
df1.loc[df1["revenue"]==35431113, "revenue"]=197436818

# %%
df.where(df["budget"]>0).dropna(subset=["budget"])
# Out:
#          adult                              belongs_to_collection      budget  \
# 0        False  {'id': 10194, 'name': 'Toy Story Collection', ...    400000.0
# 1   5412055452                                         5412055452      8520.0
# 2        False  {'id': 119050, 'name': 'Grumpy Old Men Collect...   1234785.0
# 3        False                                                NaN  16000000.0
# 5        False                                                NaN  60000000.0
# 6        False                                                NaN  58000000.0
# 8        False                                                NaN  35000000.0
# 9        False  {'id': 645, 'name': 'James Bond Collection', '...  58000000.0
# 10       False                                                NaN  62000000.0
# 13       False                                                NaN  44000000.0
# 14       False                                                NaN  98000000.0
# ...

# %%
df
# Out:
#          adult                              belongs_to_collection    budget  \
# 0        False  {'id': 10194, 'name': 'Toy Story Collection', ...    400000
# 1   5412055452                                         5412055452      8520
# 2        False  {'id': 119050, 'name': 'Grumpy Old Men Collect...   1234785
# 3        False                                                NaN  16000000
# 4        False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5        False                                                NaN  60000000
# 6        False                                                NaN  58000000
# 7        False                                                NaN         0
# 8        False                                                NaN  35000000
# 9        False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10       False                                                NaN  62000000
# ...

# %%
df.query("budget==0", inplace=True)

# %%
df
# Out:
#     adult                              belongs_to_collection  budget  \
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...       0
# 7   False                                                NaN       0
# 11  False                                                NaN       0
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...       0
# 21  False                                                NaN       0
# 23  False                                                NaN       0
# 25  False                                                NaN       0
# 27  False                                                NaN       0
# 29  False                                                NaN       0
# 31  False                                                NaN       0
# 33  False                                                NaN       0
# 35  False                                                NaN       0
# 36  False                                                NaN       0
# ...

# %%
df.query("original_language in  ['en']")
# Out:
#     adult                              belongs_to_collection  budget  \
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...       0
# 7   False                                                NaN       0
# 11  False                                                NaN       0
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...       0
# 21  False                                                NaN       0
# 23  False                                                NaN       0
# 25  False                                                NaN       0
# 27  False                                                NaN       0
# 29  False                                                NaN       0
# 33  False                                                NaN       0
# 35  False                                                NaN       0
# 36  False                                                NaN       0
# 38  False                                                NaN       0
# ...

# %%
df.apply(lambda x:x+x, axis=1)
# Out:
#     adult                              belongs_to_collection  budget  \
# 4       0  {'id': 96871, 'name': 'Father of the Bride Col...       0
# 7       0                                                NaN       0
# 11      0                                                NaN       0
# 12      0  {'id': 117693, 'name': 'Balto Collection', 'po...       0
# 21      0                                                NaN       0
# 23      0                                                NaN       0
# 25      0                                                NaN       0
# 27      0                                                NaN       0
# 29      0                                                NaN       0
# 31      0                                                NaN       0
# 33      0                                                NaN       0
# 35      0                                                NaN       0
# 36      0                                                NaN       0
# ...

# %%
df
# Out:
#     adult                              belongs_to_collection  budget  \
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...       0
# 7   False                                                NaN       0
# 11  False                                                NaN       0
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...       0
# 21  False                                                NaN       0
# 23  False                                                NaN       0
# 25  False                                                NaN       0
# 27  False                                                NaN       0
# 29  False                                                NaN       0
# 31  False                                                NaN       0
# 33  False                                                NaN       0
# 35  False                                                NaN       0
# 36  False                                                NaN       0
# ...
